# %%
import pandas as pd

df = pd.read_csv (r'C:\Users\GNR\Desktop\data\git_repos\RQ1Dataset.csv',sep = ',')
df
# Out:
#                System  PullNumber   User_login   User_id  Is_Merged  \
# 0       jquery/jquery        3900         wenz    147852      False
# 1       jquery/jquery        4140         mgol   1758366       True
# 2       jquery/jquery        1983      agcolom    688413      False
# 3       jquery/jquery        3435   pk-karthik  19588484      False
# 4       jquery/jquery        2092     markelog    945528      False
# ...               ...         ...          ...       ...        ...
# 189694  neovim/neovim        3882  sethjackson   6191831      False
# 189695  neovim/neovim        6265     justinmk   1359421       True
# 189696  neovim/neovim        5542        mhinz    972014       True
# 189697  neovim/neovim        7943    sohnryang  15506585      False
# 189698  neovim/neovim        2166        ghost     10137       True
#
#                                    Merged_commit  Age  Is_Intra_Branch  \
# 0                                            NaN    0            False
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df1 = pd.read_csv (r'C:\Users\GNR\Desktop\data\git_repos\metadata\couchbase-java-client.csv',sep = ',')
df1

# %%
df2 = pd.read_csv (r'C:\Users\GNR\Desktop\data\dryad_data\repos_data_nn.csv',sep = ',')
df2
