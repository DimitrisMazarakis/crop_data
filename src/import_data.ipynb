# %%
import pandas as pd
import glob
import ntpath

# %%
# Get CSV files list from a folder
path = 'C:/Users/GNR/Desktop/data/git_repos/crop_data/data/metadata'
csv_files = glob.glob(path + "/*.csv")

# Read each CSV file into DataFrame
# This creates a list of dataframes
df_list = (pd.read_csv(file,sep = ',') for file in csv_files)

# Concatenate all DataFrames
metadata = pd.concat(df_list, ignore_index=True)
metadata.rename(columns={'author':'main_author'}, inplace=True)
metadata
# Out:
#                 id  review_number  revision_number    main_author     status  \
# 0       12027_rev1          12027                1  Emerson Nolan  ABANDONED
# 1       12050_rev1          12050                1  Emerson Nolan     MERGED
# 2       12050_rev2          12050                2  Emerson Nolan     MERGED
# 3       12050_rev3          12050                3  Emerson Nolan     MERGED
# 4       12050_rev4          12050                4  Emerson Nolan     MERGED
# ...            ...            ...              ...            ...        ...
# 144901  85939_rev1          85939                1   Johan Savage  ABANDONED
# 144902  85948_rev1          85948                1   Emely Wilson     MERGED
# 144903  85948_rev2          85948                2   Emely Wilson     MERGED
# 144904  85957_rev1          85957                1   Emely Wilson     MERGED
# 144905  85957_rev2          85957                2   Emely Wilson     MERGED
#
#                                         change_id  \
# 0       I634fb3ea0b12e60b8d8b27d9aa3f36d5f394d83e
# 1       Idd6454bd6574a9337528281df912f51a9fda52ad
# 2       Idd6454bd6574a9337528281df912f51a9fda52ad
# 3       Idd6454bd6574a9337528281df912f51a9fda52ad
# 4       Idd6454bd6574a9337528281df912f51a9fda52ad
# ...                                           ...
# 144901  I116a423fc451b41fa324ddae18a9703f9b96c4df
# 144902  I20931d6a69996c5d569bca62bd5b7acf5469f98a
# 144903  I20931d6a69996c5d569bca62bd5b7acf5469f98a
# 144904  I6fdb6c92a74cda225a1ae82b732111754a27735b
# 144905  I6fdb6c92a74cda225a1ae82b732111754a27735b
#
#                                             url  \
# 0       http://review.couchbase.org/#/c/12027/1
# 1       http://review.couchbase.org/#/c/12050/1
# 2       http://review.couchbase.org/#/c/12050/2
# 3       http://review.couchbase.org/#/c/12050/3
# 4       http://review.couchbase.org/#/c/12050/4
# ...                                         ...
# 144901  http://review.couchbase.org/#/c/85939/1
# 144902  http://review.couchbase.org/#/c/85948/1
# 144903  http://review.couchbase.org/#/c/85948/2
# 144904  http://review.couchbase.org/#/c/85957/1
# 144905  http://review.couchbase.org/#/c/85957/2
#
#                        original_before_commit_id  \
# 0       b73b6c8f30dd87337f9fb68349bfdace565c48c8
# 1       31f14b3b541cf1322f76683ff93947389a92f39b
# 2       31f14b3b541cf1322f76683ff93947389a92f39b
# 3       627edb710baa868773d5f09e6ee1842ceff34fe8
# 4       627edb710baa868773d5f09e6ee1842ceff34fe8
# ...                                          ...
# 144901  c5009ed862c18aea4e5848f703c3bab8d8c8affb
# 144902  8585de657e924878715ebfc49ce61be290fbde6f
# 144903  c5009ed862c18aea4e5848f703c3bab8d8c8affb
# 144904  08e40583a97e81d8b806706fa08dbaccb24b53ec
# 144905  81442a1c9d2530ab7ab2d1a87bfa04eb89ce4568
#
#                         original_after_commit_id  \
# 0       634fb3ea0b12e60b8d8b27d9aa3f36d5f394d83e
# 1       dd6454bd6574a9337528281df912f51a9fda52ad
# 2       8c338944a8c4e5e068db7009c41be5cbcb8b72f1
# 3       eddbfeac3b56721994ab0bdc7a63ded3aec6bb1a
# 4       ced15bea74bce3e242865edd18d5cb1370d2eecb
# ...                                          ...
# 144901  c9d7b2eaaf452e75925255a77f265c049b5c5b57
# 144902  08e40583a97e81d8b806706fa08dbaccb24b53ec
# 144903  81442a1c9d2530ab7ab2d1a87bfa04eb89ce4568
# 144904  f46758df755d9ad5d510add3f128ad7a83ded20b
# 144905  0959b5a83b848343dced887b034e49308c53097e
#
#                                 before_commit_id  \
# 0       2a7010a1c308cf0e635fdc5fc2bb5f50890fe9c6
# 1       2c9169e853fd0dafc3a4a7779cd557247fc0e1cf
# 2       b28453bc3192cd4f5ef3c5ba60a6cef08dbb3e86
# 3       5e304c853e6ab952cc609ef3b002b1d5f91b7ca6
# 4       6cbf9ff09a6ec466c1fca2679d25b7293f3e41c8
# ...                                          ...
# 144901  084583792c84d761b8fc2980be7c080ec92f7ff5
# 144902  98cc475c634931f7dd59c50614548ddd2012f445
# 144903  b0645bbe00d8d82d55069b3d8352409bf7f755bf
# 144904  4c982463a76ebdaee7c26fdbc5da772ecd99e5e2
# 144905  edd4fab0786bc9b32d4800d93221fb62039cbb0e
#
#                                  after_commit_id
# 0       477f41586f6d8b6be8466953bfa3f9efd7a876c9
# 1       f673e5a792e2524ba861acc4a04d616d6d9c89c6
# 2       01c1711614c71b4758bb2774a2384328e41acebe
# 3       93cd8ce2ac163e4ce4fab92e3f14510bfd39d128
# 4       1fcc9544e39e0834084f5050186adb1ed2fa4a7f
# ...                                          ...
# 144901  f68f243677e638dd6f334cd3c6b89ec0a1856d9f
# 144902  3e68442eea4fe9eb3c96e6d146896b886d3b7077
# 144903  848fe1eb11237f734649c48d8760f3b34bc30dc3
# 144904  a00b168dbdb8e9fc1ead44ed1a0a38d940f63db7
# 144905  7f151a9803bc318336bf88217e4e506b427d8f07
#
# [144906 rows x 11 columns]

# %% [markdown]
# Add _discussion.txt in the end of Pull request number in order to compare them with all_discussion_specs dataframe from below.

# %%
metadata['id'] = metadata['id'].astype(str) + '_discussion.txt'

# %% [markdown]
# Pr_number column will be used for merge reasons.

# %%
metadata['PR_number'] = metadata['id'].astype(str).str[:10]

# %%
metadata
# Out:
#                                id  review_number  revision_number  \
# 0       12027_rev1_discussion.txt          12027                1
# 1       12050_rev1_discussion.txt          12050                1
# 2       12050_rev2_discussion.txt          12050                2
# 3       12050_rev3_discussion.txt          12050                3
# 4       12050_rev4_discussion.txt          12050                4
# ...                           ...            ...              ...
# 144901  85939_rev1_discussion.txt          85939                1
# 144902  85948_rev1_discussion.txt          85948                1
# 144903  85948_rev2_discussion.txt          85948                2
# 144904  85957_rev1_discussion.txt          85957                1
# 144905  85957_rev2_discussion.txt          85957                2
#
#           main_author     status                                  change_id  \
# 0       Emerson Nolan  ABANDONED  I634fb3ea0b12e60b8d8b27d9aa3f36d5f394d83e
# 1       Emerson Nolan     MERGED  Idd6454bd6574a9337528281df912f51a9fda52ad
# 2       Emerson Nolan     MERGED  Idd6454bd6574a9337528281df912f51a9fda52ad
# 3       Emerson Nolan     MERGED  Idd6454bd6574a9337528281df912f51a9fda52ad
# 4       Emerson Nolan     MERGED  Idd6454bd6574a9337528281df912f51a9fda52ad
# ...               ...        ...                                        ...
# 144901   Johan Savage  ABANDONED  I116a423fc451b41fa324ddae18a9703f9b96c4df
# 144902   Emely Wilson     MERGED  I20931d6a69996c5d569bca62bd5b7acf5469f98a
# 144903   Emely Wilson     MERGED  I20931d6a69996c5d569bca62bd5b7acf5469f98a
# 144904   Emely Wilson     MERGED  I6fdb6c92a74cda225a1ae82b732111754a27735b
# 144905   Emely Wilson     MERGED  I6fdb6c92a74cda225a1ae82b732111754a27735b
#
#                                             url  \
# 0       http://review.couchbase.org/#/c/12027/1
# 1       http://review.couchbase.org/#/c/12050/1
# 2       http://review.couchbase.org/#/c/12050/2
# 3       http://review.couchbase.org/#/c/12050/3
# 4       http://review.couchbase.org/#/c/12050/4
# ...                                         ...
# 144901  http://review.couchbase.org/#/c/85939/1
# 144902  http://review.couchbase.org/#/c/85948/1
# 144903  http://review.couchbase.org/#/c/85948/2
# 144904  http://review.couchbase.org/#/c/85957/1
# 144905  http://review.couchbase.org/#/c/85957/2
#
#                        original_before_commit_id  \
# 0       b73b6c8f30dd87337f9fb68349bfdace565c48c8
# 1       31f14b3b541cf1322f76683ff93947389a92f39b
# 2       31f14b3b541cf1322f76683ff93947389a92f39b
# 3       627edb710baa868773d5f09e6ee1842ceff34fe8
# 4       627edb710baa868773d5f09e6ee1842ceff34fe8
# ...                                          ...
# 144901  c5009ed862c18aea4e5848f703c3bab8d8c8affb
# 144902  8585de657e924878715ebfc49ce61be290fbde6f
# 144903  c5009ed862c18aea4e5848f703c3bab8d8c8affb
# 144904  08e40583a97e81d8b806706fa08dbaccb24b53ec
# 144905  81442a1c9d2530ab7ab2d1a87bfa04eb89ce4568
#
#                         original_after_commit_id  \
# 0       634fb3ea0b12e60b8d8b27d9aa3f36d5f394d83e
# 1       dd6454bd6574a9337528281df912f51a9fda52ad
# 2       8c338944a8c4e5e068db7009c41be5cbcb8b72f1
# 3       eddbfeac3b56721994ab0bdc7a63ded3aec6bb1a
# 4       ced15bea74bce3e242865edd18d5cb1370d2eecb
# ...                                          ...
# 144901  c9d7b2eaaf452e75925255a77f265c049b5c5b57
# 144902  08e40583a97e81d8b806706fa08dbaccb24b53ec
# 144903  81442a1c9d2530ab7ab2d1a87bfa04eb89ce4568
# 144904  f46758df755d9ad5d510add3f128ad7a83ded20b
# 144905  0959b5a83b848343dced887b034e49308c53097e
#
#                                 before_commit_id  \
# 0       2a7010a1c308cf0e635fdc5fc2bb5f50890fe9c6
# 1       2c9169e853fd0dafc3a4a7779cd557247fc0e1cf
# 2       b28453bc3192cd4f5ef3c5ba60a6cef08dbb3e86
# 3       5e304c853e6ab952cc609ef3b002b1d5f91b7ca6
# 4       6cbf9ff09a6ec466c1fca2679d25b7293f3e41c8
# ...                                          ...
# 144901  084583792c84d761b8fc2980be7c080ec92f7ff5
# 144902  98cc475c634931f7dd59c50614548ddd2012f445
# 144903  b0645bbe00d8d82d55069b3d8352409bf7f755bf
# 144904  4c982463a76ebdaee7c26fdbc5da772ecd99e5e2
# 144905  edd4fab0786bc9b32d4800d93221fb62039cbb0e
#
#                                  after_commit_id   PR_number
# 0       477f41586f6d8b6be8466953bfa3f9efd7a876c9  12027_rev1
# 1       f673e5a792e2524ba861acc4a04d616d6d9c89c6  12050_rev1
# 2       01c1711614c71b4758bb2774a2384328e41acebe  12050_rev2
# 3       93cd8ce2ac163e4ce4fab92e3f14510bfd39d128  12050_rev3
# 4       1fcc9544e39e0834084f5050186adb1ed2fa4a7f  12050_rev4
# ...                                          ...         ...
# 144901  f68f243677e638dd6f334cd3c6b89ec0a1856d9f  85939_rev1
# 144902  3e68442eea4fe9eb3c96e6d146896b886d3b7077  85948_rev1
# 144903  848fe1eb11237f734649c48d8760f3b34bc30dc3  85948_rev2
# 144904  a00b168dbdb8e9fc1ead44ed1a0a38d940f63db7  85957_rev1
# 144905  7f151a9803bc318336bf88217e4e506b427d8f07  85957_rev2
#
# [144906 rows x 12 columns]

# %% [markdown]
# For discussion data.

# %%
def add_value(dict_obj, key, value):
    ''' Adds a key-value pair to the dictionary.
        If the key already exists in the dictionary, 
        it will associate multiple values with that 
        key instead of overwritting its value'''
    if key not in dict_obj:
        dict_obj[key] = value
    elif isinstance(dict_obj[key], list):
        dict_obj[key].append(value)
    else:
        dict_obj[key] = [dict_obj[key], value]

# %% [markdown]
# Find all commit messages and descriptions for all files

# %%
files_path = glob.glob('C:/Users/GNR/Desktop/data/git_repos/crop_data/data/discussion/*/*/*.txt')
commit_messages={}
descriptions={}
all_comments = {}
all_authors = {}
all_dates = {}

for file_path in files_path:
    comments = {}
    comments_limits=[]
    authors = {}
    dates = {}
    file = open(file_path, encoding='utf8')
# Checks for commit messages
    for x, line in enumerate(file):
        if line[:12] == "First commit":
            commit_message_start = x
        if line[:10] == "Change-Id:":
            commit_message_end = x
            break
    file.close()
# Checks for description
    file = open(file_path, encoding='utf8')
    for x, line in enumerate(file):
# If it has a commit message
        if line[:12] == "First commit":
            description_end = x
            break
        if line[:10] == "Change-Id:":
            description_end = x
            break
    file.close()
    file = open(file_path, encoding='utf8')
    
    # Check for Comments
    file = open(file_path, encoding='utf8')
    for x, line in enumerate(file):
        if line[:5] == "date:":
            start = x
        if line[:10] == "----------":
            end = x
            tup=(start,end)
            comments_limits.append(tup)
    file.close()
    
    comment = ""
    author = ""
    date = ""
    commit_message = ""
    description = ""
    # Saves all commit messages and descriptions
    file = open(file_path, encoding='utf8')
    for x, line in enumerate(file):
        if x > commit_message_start and x < commit_message_end:
            commit_message+=line
        if x > 1 and x < description_end:
            description+=line
    add_value(commit_messages, ntpath.basename(file_path)[:10], commit_message.replace("\n",""))
    add_value(descriptions, ntpath.basename(file_path)[:10], description.replace("\n",""))
    file.close()
    
    # Saving the comments, author and dates of the comments
    for tuple in comments_limits:
        file = open(file_path, encoding='utf8')
        for x, line in enumerate(file):
            if x > tuple[0] and x < tuple[1]:
                comment+=line
            if x == tuple[0]-1:
                author+=line[8:]
            if x == tuple[0]:
                date+=line[6:]
        add_value(comments, ntpath.basename(file_path)[:10], comment.replace("\n",""))
        add_value(authors, ntpath.basename(file_path)[:10], author.replace("\n",""))
        add_value(dates, ntpath.basename(file_path)[:10], date.replace("\n",""))
        comment = ""
        author = ""
        date = ""
        file.close()
    all_comments.update(comments)
    all_authors.update(authors)
    all_dates.update(dates)

    file.close()

# %%
len(commit_messages)
# Out:
# 131177

# %% [markdown]
# Convert lists to dataframes

# %%
all_comments_df = pd.Series(all_comments, name='Comment').rename_axis('PR_number').explode().reset_index()
all_authors_df = pd.Series(all_authors, name='Author').rename_axis('PR_number').explode().reset_index()
all_dates_df = pd.Series(all_dates, name='Date').rename_axis('PR_number').explode().reset_index()
commit_messages_df = pd.Series(commit_messages, name='Commit_message').rename_axis('PR_number').explode().reset_index()
descriptions_df = pd.Series(descriptions, name='Description').rename_axis('PR_number').explode().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\GNR\Desktop\data\git_repos\crop_data\src\import_data.ipynb Cell 14' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/GNR/Desktop/data/git_repos/crop_data/src/import_data.ipynb#ch0000013?line=0'>1</a> all_comments_df = pd.Series(all_comments, name='Comment').rename_axis('PR_number').explode().reset_index()
#       <a href='vscode-notebook-cell:/c%3A/Users/GNR/Desktop/data/git_repos/crop_data/src/import_data.ipynb#ch0000013?line=1'>2</a> all_authors_df = pd.Series(all_authors, name='Author').rename_axis('PR_number').explode().reset_index()
#       <a href='vscode-notebook-cell:/c%3A/Users/GNR/Desktop/data/git_repos/crop_data/src/import_data.ipynb#ch0000013?line=2'>3</a> all_dates_df = pd.Series(all_dates, name='Date').rename_axis('PR_number').explode().reset_index()
#
# NameError: name 'pd' is not defined

# %%
commit_messages_df
# Out:
#          PR_number                                     Commit_message
# 0       11287_rev1  * Transferred all of the Couchbase code from s...
# 1       11287_rev2  * Transferred all of the Couchbase code from s...
# 2       11287_rev3  * Transferred all of the Couchbase code from s...
# 3       12027_rev1  Checked buckets for power of 2 (according to s...
# 4       12027_rev1  IMenuService#populateContributionManager(*)Wor...
# ...            ...                                                ...
# 153236  9927_rev1_
# 153237  9977_rev1_
# 153238  9977_rev2_
# 153239  9977_rev3_
# 153240  9988_rev2_
#
# [153241 rows x 2 columns]

# %% [markdown]
# Merge all dataframes to one

# %%
all_discussion_specs = pd.merge(all_comments_df, all_authors_df, right_index = True, left_index = True)
del all_discussion_specs['PR_number_y']

# %%
all_discussion_specs = pd.merge(all_discussion_specs, all_dates_df, right_index = True, left_index = True)
del all_discussion_specs['PR_number_x']
all_discussion_specs
# Out:
#                                                   Comment         Author  \
# 0                                   Uploaded patch set 2.   Jeffrey Roth
# 1                                   Uploaded patch set 3.   Jeffrey Roth
# 2       Patch Set 3: Looks good to me, approvedI'm sur...  Kenny Maynard
# 3                                   Patch Set 3: Verified   Jeffrey Roth
# 4       Change has been successfully merged into the g...   Jeffrey Roth
# ...                                                   ...            ...
# 437051  Patch Set 3: Looks good to me, approvedRubbers...    Reid Stokes
# 437052  Change has been successfully cherry-picked as ...    Reid Stokes
# 437053                              Uploaded patch set 2.    Ayden Rivas
# 437054  Patch Set 2: Verified; Looks good to me, approved   Zackery Barr
# 437055  Change has been successfully cherry-picked as ...   Zackery Barr
#
#          PR_number                           Date
# 0       11287_rev2  2012-01-03 22:42:46.755000000
# 1       11287_rev3  2012-01-04 00:15:52.130000000
# 2       11287_rev3  2012-01-04 00:23:41.182000000
# 3       11287_rev3  2012-01-04 00:49:35.390000000
# 4       11287_rev3  2012-01-04 00:49:35.587000000
# ...            ...                            ...
# 437051  9977_rev3_  2011-10-08 01:42:12.137000000
# 437052  9977_rev3_  2011-10-08 01:42:16.091000000
# 437053  9988_rev2_  2011-10-06 22:47:10.792000000
# 437054  9988_rev2_  2011-10-06 22:48:26.810000000
# 437055  9988_rev2_  2011-10-06 22:48:28.498000000
#
# [437056 rows x 4 columns]

# %%
commits_and_descriptions = commit_messages_df.merge(descriptions_df, on='PR_number')

# %%
all_discussion_specs = all_discussion_specs.merge(commits_and_descriptions, on='PR_number', how='outer')

# %%
all_discussion_specs
# Out:
#                                                   Comment         Author  \
# 0                                   Uploaded patch set 2.   Jeffrey Roth
# 1                                   Uploaded patch set 3.   Jeffrey Roth
# 2       Patch Set 3: Looks good to me, approvedI'm sur...  Kenny Maynard
# 3                                   Patch Set 3: Verified   Jeffrey Roth
# 4       Change has been successfully merged into the g...   Jeffrey Roth
# ...                                                   ...            ...
# 875425                                                NaN            NaN
# 875426                                                NaN            NaN
# 875427                                                NaN            NaN
# 875428                                                NaN            NaN
# 875429                                                NaN            NaN
#
#          PR_number                           Date  \
# 0       11287_rev2  2012-01-03 22:42:46.755000000
# 1       11287_rev3  2012-01-04 00:15:52.130000000
# 2       11287_rev3  2012-01-04 00:23:41.182000000
# 3       11287_rev3  2012-01-04 00:49:35.390000000
# 4       11287_rev3  2012-01-04 00:49:35.587000000
# ...            ...                            ...
# 875425  9585_rev1_                            NaN
# 875426  9626_rev1_                            NaN
# 875427  9670_rev1_                            NaN
# 875428  9705_rev1_                            NaN
# 875429  9977_rev1_                            NaN
#
#                                            Commit_message  \
# 0       * Transferred all of the Couchbase code from s...
# 1       * Transferred all of the Couchbase code from s...
# 2       * Transferred all of the Couchbase code from s...
# 3       * Transferred all of the Couchbase code from s...
# 4       * Transferred all of the Couchbase code from s...
# ...                                                   ...
# 875425
# 875426
# 875427  Added four upgradetests:-1- in-place upgrade f...
# 875428  INI resource file can have entries as followin...
# 875429
#
#                                               Description
# 0
# 1
# 2
# 3
# 4
# ...                                                   ...
# 875425                        add jenkins rebalance tests
# 875426  adding timeout as an option to direct and prox...
# 875427  Add support for Multiple version upgradeAdded ...
# 875428  Add support for cluster tag in resource fileIN...
# 875429   Catch exceptions when connecting with SSH Client
#
# [875430 rows x 6 columns]

# %%
all_data = all_discussion_specs.merge(metadata[['PR_number','status']], on='PR_number')

# %%
# pd.set_option('display.max_rows', None)

# %%
all_data
# Out:
#                                                    Comment         Author  \
# 0        Patch Set 1: I would prefer that you didn't su...  Kenny Maynard
# 1        Patch Set 1: I would prefer that you didn't su...  Kenny Maynard
# 2        Patch Set 1: I would prefer that you didn't su...  Kenny Maynard
# 3        Patch Set 1: I would prefer that you didn't su...  Kenny Maynard
# 4        Patch Set 1: I would prefer that you didn't su...  Kenny Maynard
# ...                                                    ...            ...
# 3943426                                                NaN            NaN
# 3943427                                                NaN            NaN
# 3943428                                                NaN            NaN
# 3943429                                                NaN            NaN
# 3943430                                                NaN            NaN
#
#           PR_number                           Date  \
# 0        12027_rev1  2012-01-03 22:37:04.706000000
# 1        12027_rev1  2012-01-03 22:37:04.706000000
# 2        12027_rev1  2012-01-03 22:37:04.706000000
# 3        12027_rev1  2012-01-03 22:37:04.706000000
# 4        12027_rev1  2012-01-03 22:37:04.706000000
# ...             ...                            ...
# 3943426  9585_rev1_                            NaN
# 3943427  9626_rev1_                            NaN
# 3943428  9670_rev1_                            NaN
# 3943429  9705_rev1_                            NaN
# 3943430  9977_rev1_                            NaN
#
#                                             Commit_message  \
# 0        Checked buckets for power of 2 (according to s...
# 1        Checked buckets for power of 2 (according to s...
# 2        Checked buckets for power of 2 (according to s...
# 3        Checked buckets for power of 2 (according to s...
# 4        IMenuService#populateContributionManager(*)Wor...
# ...                                                    ...
# 3943426
# 3943427
# 3943428  Added four upgradetests:-1- in-place upgrade f...
# 3943429  INI resource file can have entries as followin...
# 3943430
#
#                                                Description     status
# 0                                                           ABANDONED
# 1                                                              MERGED
# 2        Bug 366528 - [Compatibility] ImplementIMenuSer...  ABANDONED
# 3        Bug 366528 - [Compatibility] ImplementIMenuSer...     MERGED
# 4                                                           ABANDONED
# ...                                                    ...        ...
# 3943426                        add jenkins rebalance tests     MERGED
# 3943427  adding timeout as an option to direct and prox...     MERGED
# 3943428  Add support for Multiple version upgradeAdded ...     MERGED
# 3943429  Add support for cluster tag in resource fileIN...     MERGED
# 3943430   Catch exceptions when connecting with SSH Client     MERGED
#
# [3943431 rows x 7 columns]

# %%
compression_opts = dict(method='zip',
                        archive_name='all_data.csv') 
all_data.to_csv('all_data.zip', index=False, compression=compression_opts)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\GNR\Desktop\data\git_repos\crop_data\src\import_data.ipynb Cell 24' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/GNR/Desktop/data/git_repos/crop_data/src/import_data.ipynb#ch0000023?line=0'>1</a> compression_opts = dict(method='zip',
#       <a href='vscode-notebook-cell:/c%3A/Users/GNR/Desktop/data/git_repos/crop_data/src/import_data.ipynb#ch0000023?line=1'>2</a>                         archive_name='all_data.csv')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/GNR/Desktop/data/git_repos/crop_data/src/import_data.ipynb#ch0000023?line=2'>3</a> all_data.to_csv('all_data.zip', index=False, compression=compression_opts)
#
# File c:\Python\Python38\lib\site-packages\pandas\core\generic.py:3551, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3539'>3540</a> df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3541'>3542</a> formatter = DataFrameFormatter(
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3542'>3543</a>     frame=df,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3543'>3544</a>     header=header,
#    (...)
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3547'>3548</a>     decimal=decimal,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3548'>3549</a> )
# -> <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3550'>3551</a> return DataFrameRenderer(formatter).to_csv(
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3551'>3552</a>     path_or_buf,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3552'>3553</a>     line_terminator=line_terminator,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3553'>3554</a>     sep=sep,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3554'>3555</a>     encoding=encoding,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3555'>3556</a>     errors=errors,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3556'>3557</a>     compression=compression,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3557'>3558</a>     quoting=quoting,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3558'>3559</a>     columns=columns,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3559'>3560</a>     index_label=index_label,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3560'>3561</a>     mode=mode,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3561'>3562</a>     chunksize=chunksize,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3562'>3563</a>     quotechar=quotechar,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3563'>3564</a>     date_format=date_format,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3564'>3565</a>     doublequote=doublequote,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3565'>3566</a>     escapechar=escapechar,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3566'>3567</a>     storage_options=storage_options,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/core/generic.py?line=3567'>3568</a> )
#
# File c:\Python\Python38\lib\site-packages\pandas\io\formats\format.py:1180, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/format.py?line=1158'>1159</a>     created_buffer = False
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/format.py?line=1160'>1161</a> csv_formatter = CSVFormatter(
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/format.py?line=1161'>1162</a>     path_or_buf=path_or_buf,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/format.py?line=1162'>1163</a>     line_terminator=line_terminator,
#    (...)
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/format.py?line=1177'>1178</a>     formatter=self.fmt,
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/format.py?line=1178'>1179</a> )
# -> <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/format.py?line=1179'>1180</a> csv_formatter.save()
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/format.py?line=1181'>1182</a> if created_buffer:
#    <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/format.py?line=1182'>1183</a>     assert isinstance(path_or_buf, StringIO)
#
# File c:\Python\Python38\lib\site-packages\pandas\io\formats\csvs.py:261, in CSVFormatter.save(self)
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=240'>241</a> with get_handle(
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=241'>242</a>     self.filepath_or_buffer,
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=242'>243</a>     self.mode,
#    (...)
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=248'>249</a>
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=249'>250</a>     # Note: self.encoding is irrelevant here
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=250'>251</a>     self.writer = csvlib.writer(
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=251'>252</a>         handles.handle,
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=252'>253</a>         lineterminator=self.line_terminator,
#    (...)
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=257'>258</a>         quotechar=self.quotechar,
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=258'>259</a>     )
# --> <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=260'>261</a>     self._save()
#
# File c:\Python\Python38\lib\site-packages\pandas\io\formats\csvs.py:266, in CSVFormatter._save(self)
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=263'>264</a> if self._need_to_save_header:
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=264'>265</a>     self._save_header()
# --> <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=265'>266</a> self._save_body()
#
# File c:\Python\Python38\lib\site-packages\pandas\io\formats\csvs.py:304, in CSVFormatter._save_body(self)
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=301'>302</a> if start_i >= end_i:
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=302'>303</a>     break
# --> <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=303'>304</a> self._save_chunk(start_i, end_i)
#
# File c:\Python\Python38\lib\site-packages\pandas\io\formats\csvs.py:315, in CSVFormatter._save_chunk(self, start_i, end_i)
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=311'>312</a> data = [res.iget_values(i) for i in range(len(res.items))]
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=313'>314</a> ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=314'>315</a> libwriters.write_csv_rows(
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=315'>316</a>     data,
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=316'>317</a>     ix,
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=317'>318</a>     self.nlevels,
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=318'>319</a>     self.cols,
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=319'>320</a>     self.writer,
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/formats/csvs.py?line=320'>321</a> )
#
# File c:\Python\Python38\lib\site-packages\pandas\_libs\writers.pyx:72, in pandas._libs.writers.write_csv_rows()
#
# File c:\Python\Python38\lib\site-packages\pandas\io\common.py:910, in _BytesZipFile.write(self, data)
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/common.py?line=905'>906</a> if self.multiple_write_buffer is None:
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/common.py?line=906'>907</a>     self.multiple_write_buffer = (
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/common.py?line=907'>908</a>         BytesIO() if isinstance(data, bytes) else StringIO()
#     <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/common.py?line=908'>909</a>     )
# --> <a href='file:///c%3A/Python/Python38/lib/site-packages/pandas/io/common.py?line=909'>910</a> self.multiple_write_buffer.write(data)
#
# MemoryError:

# %%
if '11287_rev1' in all_discussion_specs['PR_number'].values :
    print("\nThis value exists in Dataframe")
# Out:
# This value exists in Dataframe

# %% [markdown]
# For a single file (Testing)

# %%
import ntpath
path = 'C:/Users/GNR/Desktop/data/git_repos/crop_data/data/discussion/couchbase-java-client/11287/11287_rev3_discussion.txt'
file = open('C:/Users/GNR/Desktop/data/git_repos/crop_data/data/discussion/couchbase-java-client/11287/11287_rev3_discussion.txt')
commit_messages={}
comments = {}
comments_limits=[]
authors = {}
dates = {}
# Checks for commit messages
for x, line in enumerate(file):
    if line[:12] == "First commit":
         commit_message_start = x
    if line[:10] == "Change-Id:":
        commit_message_end = x
        break
file.close()
# Checks for description
file = open('C:/Users/GNR/Desktop/data/git_repos/crop_data/data/discussion/couchbase-java-client/11287/11287_rev3_discussion.txt')
for x, line in enumerate(file):
# If it has a commit message
    if line[:12] == "First commit":
        description_end = x
        break
    if line[:10] == "Change-Id:":
        description_end = x
        break
file.close()
# Check for Comments
file = open('C:/Users/GNR/Desktop/data/git_repos/crop_data/data/discussion/couchbase-java-client/11287/11287_rev3_discussion.txt')
for x, line in enumerate(file):
    if line[:5] == "date:":
        start = x
    if line[:10] == "----------":
        end = x
        tup=(start,end)
        comments_limits.append(tup)
file.close()

commit_message = ""
comment = ""
author = ""
date = ""
# For each comment in the text file
for tuple in comments_limits:
    file = open('C:/Users/GNR/Desktop/data/git_repos/crop_data/data/discussion/couchbase-java-client/11287/11287_rev3_discussion.txt')
    for x, line in enumerate(file):
        if x > tuple[0] and x < tuple[1]:
            comment+=line
# Saving the author
        if x == tuple[0]-1:
            author+=line[8:]
        if x == tuple[0]:
            date+=line[6:]
    add_value(comments, ntpath.basename(path)[:10], comment.replace("\n",""))
    #comments = ({comment.replace("\n",""),ntpath.basename("r'C:/Users/GNR/Desktop/data/git_repos/crop_data/data/discussion/couchbase-java-client/11287/11287_rev3_discussion.txt'")[:10]})
    add_value(authors, ntpath.basename("r'C:/Users/GNR/Desktop/data/git_repos/crop_data/data/discussion/couchbase-java-client/11287/11287_rev3_discussion.txt'")[:10], date.replace("\n",""))
    add_value(dates, ntpath.basename("r'C:/Users/GNR/Desktop/data/git_repos/crop_data/data/discussion/couchbase-java-client/11287/11287_rev3_discussion.txt'")[:10], author.replace("\n",""))
    comment = ""
    author = ""
    date = ""
    file.close()

#commit_messages.append(commit_message.replace('\n',""))
file.close()
print(dates)
import os
#print(os.path.splitext('C:/Users/GNR/Desktop/data/git_repos/crop_data/data/discussion/couchbase-java-client/11287/11287_rev3_discussion.txt', sep="//")[0])

print(comments)
#print(ntpath.basename("r'C:/Users/GNR/Desktop/data/git_repos/crop_data/data/discussion/couchbase-java-client/11287/11287_rev3_discussion.txt'")[:10])
# Out:
# {'11287_rev3': ['Jeffrey Roth', 'Kenny Maynard', 'Jeffrey Roth', 'Jeffrey Roth']}
# {'11287_rev3': ['Uploaded patch set 3.', 'Patch Set 3: Looks good to me, approvedI\'m sure you\'ve been over this with Matt, but just in case you haven\'t the last steps to committing something are to run the tests on this change. If they pass then mark that you have verified the code and click "publish and submit"', 'Patch Set 3: Verified', 'Change has been successfully merged into the git repository.']}
